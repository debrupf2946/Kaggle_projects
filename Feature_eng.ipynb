# %%
import os
import urllib
import matplotlib.pyplot as plt 
import pandas as pd

# %%
import os

PROJECT_ROOT_DIR = "."
CHAPTER_ID = "unsupervised_learning"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

images_path = os.path.join(PROJECT_ROOT_DIR, "images", "unsupervised_learning")
os.makedirs(images_path, exist_ok=True)
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
filename = "ladybug.png"
print("Downloading", filename)
url = DOWNLOAD_ROOT + "images/unsupervised_learning/" + filename
urllib.request.urlretrieve(url, os.path.join(images_path, filename))
# Out:
# Downloading ladybug.png
# ('./images/unsupervised_learning/ladybug.png',
#  <http.client.HTTPMessage at 0x117eee9b0>)

# %%
from matplotlib.image import imread
image = imread(os.path.join(images_path, filename))
image.shape
# Out:
# (533, 800, 3)

# %%
from sklearn.cluster import KMeans
X = image.reshape(-1, 3)
kmeans = KMeans(n_clusters=2, random_state=42).fit(X)
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(image.shape)
# Out:
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
segmented_imgs = []
for n_clusters in n_colors:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(X)
    segmented_img = kmeans.cluster_centers_[kmeans.labels_]
    segmented_imgs.append(segmented_img.reshape(image.shape))
# Out:
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.subplots_adjust(wspace=0.05, hspace=0.1)

plt.subplot(231)
plt.imshow(image)
plt.title("Original image")
plt.axis('off')

for idx, n_clusters in enumerate(n_colors):
    plt.subplot(232 + idx)
    plt.imshow(segmented_imgs[idx])
    plt.title("{} colors".format(n_clusters))
    plt.axis('off')

plt.show()

# %%
pd.read_csv("https://docs.google.com/spreadsheets/d/12plYRnpTs7UWvbwQOkc8I06dCiUBUSGXZPHQSG5_Y7Y/edit#gid=2052010527")
# Out:
#     <!doctype html><html lang="en-US" dir="ltr"><head><base href="https://accounts.google.com/v3/signin/"><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width  \
# 0    /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-i...
# 1                         (function(){var T=function(C
# 2                        '(function(){var w=function(C
# 3               Copyright The Closure Library Authors.
# 4                  SPDX-License-Identifier: Apache-2.0
# ..                                                 ...
# 113                                              g:"1"
# 114                                              h:!0}
# 115  X.prototype.j=function(){var b=this.i.querySel...
# 116                                    (f=f.replace(ka
# 117                       </script></div></div></body>
#
#      initial-scale=1"><style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.gAuTVgVrG9Q.L.X.O/am=oBxgjkMPAMr_AAECAAUKAAAAAAAAAIBAGCYl/d=1/ed=1/rs=AOaEmlH6xO8PR-jfWkgGCM08-c33_kUZdw/m=identifierview  \
# 0                                                   _b
# 1                                                    H
# 2                                                    p
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                                           index:32
# 114                              vi:{name:W.COUNTRY.VI
# 115                c=document.createDocumentFragment()
# 116                                             &lt;))
# 117                                                NaN
#
#                                       _b  \
# 0                                    _tp
# 1                                      Z
# 2                                      S
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 113                                h:!0}
# 114                                g:"1"
# 115                    d=Object.keys(Na)
# 116  -1!=f.indexOf(">")&&(f=f.replace(la
# 117                                  NaN
#
#                                                    _tp  \
# 0    _r */</style><style nonce="eqmj0xKOuORPSnbmkbJ...
# 1                                                    S
# 2    t){return(C&73)==((C^58)>>((C-(3==(C>>1&7)&&("...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                              tv:{name:W.COUNTRY.TV
# 114                                          index:140
# 115  e=(this.i.dataset.regionCode||"").toLowerCase(...
# 116                                             &gt;))
# 117                                                NaN
#
#     _r" nonce="eqmj0xKOuORPSnbmkbJe_g">c-wiz{contain:style}c-wiz>c-data{display:none}c-wiz.rETSD{contain:none}c-wiz.Ubi8Z{contain:layout style}@-webkit-keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%  \
# 0    eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cm...
# 1                                                    Y
# 2                                            t=p[CQ]))
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                                            g:"688"
# 114                                              h:!0}
# 115  l=h.name;h=f.toLowerCase()===e;var A=document....
# 116                -1!=f.indexOf('"')&&(f=f.replace(ma
# 117                                                NaN
#
#     -50%) scale(0.2);-webkit-transform:translate(-50%  \
# 0                                                 NaN
# 1                                                   W
# 2                   2)|26)<C&&C-6<<2>=C&&!S.J&&(S.J=p
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 113                                         index:21}
# 114                             vn:{name:W.COUNTRY.VN
# 115                                           &amp;))
# 116                                          &quot;))
# 117                                               NaN
#
#          -50%) scale(0.2);-ms-transform:translate(-50%  \
# 0                                                  NaN
# 1    e){return 1<=(C-3&((C&35)==((C^43)>>3||(W=func...
# 2                                               S.H())
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                              tw:{name:W.COUNTRY.TW
# 114                                             g:"84"
# 115                               -1!=f.indexOf("<")&&
# 116                -1!=f.indexOf("'")&&(f=f.replace(na
# 117                                                NaN
#
#     -50%) scale(0.2);-o-transform:translate(-50%  \
# 0                                            NaN
# 1                                       Y=void 0
# 2                      3)||(t=iI[S](iI.prototype
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 113                                      g:"886"
# 114                                    index:74}
# 115                                          NaN
# 116                                      &#39;))
# 117                                          NaN
#
#     -50%) scale(0.2);transform:translate(-50%  \
# 0                                         NaN
# 1                                       S=f(H
# 2                                    {floor:p
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 113                                 index:38}
# 114                     vu:{name:W.COUNTRY.VU
# 115                                       NaN
# 116    -1!=f.indexOf("\x00")&&(f=f.replace(oa
# 117                                       NaN
#
#     -50%) scale(0.2)}to{-webkit-transform:translate(-50%  ...  \
# 0                                                  NaN    ...
# 1                              function(p){W&&(Z&&k(Z)    ...
# 2                                                pop:p    ...
# 3                                                  NaN    ...
# 4                                                  NaN    ...
# ..                                                 ...    ...
# 113                              tz:{name:W.COUNTRY.TZ    ...
# 114                                            g:"678"    ...
# 115                                                NaN    ...
# 116                    &#0;)));if(void 0===G)if(g=null    ...
# 117                                                NaN    ...
#
#     64px)}}@media all and (max-aspect-ratio:3/2) and (orientation:landscape){.JAdVbc.AdRpFc.wsArZ[data-ss-mode="1"]{margin-left:48px;margin-left:var(--c-ps-s  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#     48px);margin-right:48px;margin-right:var(--c-ps-e.1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#     48px)}.JAdVbc.AdRpFc.NQ5OL{margin-left:48px;margin-left:var(--c-ps-s  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#     48px);margin-right:48px;margin-right:var(--c-ps-e.2  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#     48px)}}.d2laFc .wLBAL[data-email$="@glimitedaccount.com"]{display:none}.lPxAeb .yAlK0b[data-email$="@glimitedaccount.com"]{display:none}.ZWssT{margin-top:26px}.vopC4e{background:transparent;border:none;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;color:rgb(32  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#     33.21  \
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 113   NaN
# 114   NaN
# 115   NaN
# 116   NaN
# 117   NaN
#
#     36);cursor:pointer;margin-bottom:-15px;margin-top:-15px;outline:inherit;padding-bottom:15px;padding-top:15px;position:relative;z-index:1}.vopC4e:focus::after{background-color:rgba(26  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#     115.52 232.5  \
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
# ..     ...   ...
# 113    NaN   NaN
# 114    NaN   NaN
# 115    NaN   NaN
# 116    NaN   NaN
# 117    NaN   NaN
#
#     .15);-webkit-border-radius:2px;-moz-border-radius:2px;border-radius:2px;bottom:0;content:"";left:0;position:absolute;right:0;top:0;z-index:-1}.JVMrYb{display:block}.hJIRO{display:none}.sQecwc{display:hidden}sentinel{}
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
# [118 rows x 6487 columns]
