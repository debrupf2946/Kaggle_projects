# %%
import pandas as pd

# %%
path='/Users/debruppaul/Documents/ml/pandas/d1/'

# %%
df1=pd.read_csv(path+'d11.csv')
df1
# Out:
#            ID DEVICETYPE  PLATFORM_ID     BIDREQUESTIP  \
# 0      115501    Desktop            2   75.189.231.103
# 1      115502     Mobile            2    24.101.33.158
# 2      115503    Desktop            2  172.118.216.142
# 3      115504    Desktop            7   71.105.120.171
# 4      115505    Desktop            2     73.82.211.73
# ...       ...        ...          ...              ...
# 28488  143989    Desktop            2   69.202.233.241
# 28489  143990    Desktop            7      75.4.190.65
# 28490  143991    Desktop            7    137.52.180.45
# 28491  143992    Desktop            8      66.249.66.4
# 28492  143993    Desktop            2   107.194.33.149
#
#                             USERPLATFORMUID         USERCITY  USERZIPCODE  \
# 0      0d5041ff-f0b6-4d1a-9ad7-0a29f7d485b4     Fayetteville      28305.0
# 1      c8396dd0-969f-4d99-a40b-b7bb1f516154    Conneaut Lake      16316.0
# 2      3c97a081-6518-43f8-9f26-369759cfb471           Covina      91724.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28493 entries, 0 to 28492
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               28493 non-null  int64
#  1   DEVICETYPE       28493 non-null  object
#  2   PLATFORM_ID      28493 non-null  int64
#  3   BIDREQUESTIP     28493 non-null  object
#  4   USERPLATFORMUID  28493 non-null  object
#  5   USERCITY         26934 non-null  object
#  6   USERZIPCODE      27378 non-null  float64
#  7   USERAGENT        28492 non-null  object
#  8   PLATFORMTYPE     28493 non-null  object
#  9   CHANNELTYPE      28493 non-null  object
#  10  URL              28493 non-null  object
#  11  KEYWORDS         28493 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.6+ MB

# %%
df1.PLATFORMTYPE.value_counts()
# Out:
# Online Medical Journal      27533
# Online Learning Portal        762
# Medical News Platform         191
# Electronic Health Record        7
# Name: PLATFORMTYPE, dtype: int64

# %%
df1.KEYWORDS.value_counts()
# Out:
# Family Practice|Drainage|Clinical|Dermatology|Ophthalmology|Medicine|Allergic|General|Diagnosis|Neurology|Hepatology|Health|Cardiovascular|Surgical|Psychiatry|Oral|Urology|Cardiology|Gastroenterology|Orthopedics|Erythema|Arthritis|Asthma|Cellulitis|Pediatrics|Surgery|False|Oncology|Rheumatology                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1352
# ...

# %%
df1.URL.value_counts()
# Out:
# https://www.clinicaladvisor.com/home/features/clinical-challenge/pain-tingling-and-limited-range-of-motion-after-a-cat-bite-to-the-finger/                                                                                                                                               1349
# https://www.gastroenterologyadvisor.com/                                                                                                                                                                                                                                                 1043
# https://www.cureus.com/articles/105482-diverticulitis-with-microperforation                                                                                                                                                                                                               706
# ...

# %%
df1.URL[0]
df2=[]

# %%
for i in range(0,2894):
    
    df2.append(df1.URL[i].split('.')[1])

# %%
pd.DataFrame(df2).value_counts().head(50)
# Out:
# cureus                                                                                                                                                     534
# clinicaladvisor                                                                                                                                            383
# cancertherapyadvisor                                                                                                                                       256
# empr                                                                                                                                                       253
# rheumatologyadvisor                                                                                                                                        180
# gastroenterologyadvisor                                                                                                                                    164
# ...
